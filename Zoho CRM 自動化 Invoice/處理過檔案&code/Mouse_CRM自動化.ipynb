# %%
import pynput.mouse as ms
import pynput.keyboard as kb
import time
import datetime

# %%
# 移動到搜尋程式，並點選(0:00-0:06)
time.sleep(10)
myMouse = ms.Controller()
myMouse.position = (70, 700)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

# 搜尋chrome並打開(0:06-0:17)
myKeyboard = kb.Controller()
# programToFind = input('Type the program name:')
programToFind = 'chrome'
myKeyboard.type(programToFind)
time.sleep(4)
myKeyboard.tap(kb.Key.enter)
time.sleep(8)

# 點選使用者 (Sean)
myMouse.position = (641, 407)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

# 選擇模組
myMouse.position = (659, 98)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

programToFind = '出貨'
myKeyboard.type(programToFind)
time.sleep(4)
myKeyboard.tap(kb.Key.enter)
myKeyboard.tap(kb.Key.enter)
time.sleep(5)

# 點選Import 出貨下拉選單
myMouse.position = (1108, 151)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

# 點選Import 出貨
myMouse.position = (1070, 189)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

# 點選瀏覽
myMouse.position = (597, 418)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

# 點選桌面
myMouse.position = (80, 153)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

# 輸入欲Import檔案名稱
myMouse.position = (267, 417)
myMouse.click(ms.Button.left, 1)
myKeyboard.tap(kb.Key.shift)
programToFind = '004.csv'
myKeyboard.type(programToFind)
myKeyboard.tap(kb.Key.enter)
time.sleep(4)

# 點選下一步
myMouse.position = (1021, 559)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

# 點選下拉式選單
myMouse.position = (305, 354)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

# 點選出貨單號
myMouse.position = (295, 457)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

# 點選下一步
myMouse.position = (178, 441)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

# 點選Apply auto mapping
myMouse.position = (248, 621)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

# 點選Apply
myMouse.position = (692, 231)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

# 點選下一步
myMouse.position = (1213, 623)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

# 點選繼續
myMouse.position = (725, 241)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

myMouse.scroll(0, -100)
time.sleep(4)
# 點選Finish
myMouse.position = (291, 559)
myMouse.click(ms.Button.left, 2)
time.sleep(10)

# 點選Home並重新整理
myMouse.position = (260, 96)
myMouse.click(ms.Button.left, 2)
time.sleep(4)
myKeyboard.tap(kb.Key.f5)

# %%
# 移動到搜尋程式，並點選(0:00-0:06)
time.sleep(10)
myMouse = ms.Controller()
myMouse.position = (70, 700)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

# 搜尋chrome並打開(0:06-0:17)
myKeyboard = kb.Controller()
# programToFind = input('Type the program name:')
programToFind = 'chrome'
myKeyboard.type(programToFind)
time.sleep(4)
myKeyboard.tap(kb.Key.enter)
time.sleep(8)

# 點選使用者 (Sean)
myMouse.position = (641, 407)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

# 選擇模組
myMouse.position = (659, 98)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

programToFind = '出貨明細'
myKeyboard.type(programToFind)
time.sleep(4)
myKeyboard.tap(kb.Key.enter)
myKeyboard.tap(kb.Key.enter)
time.sleep(5)

# 點選Import 出貨明細下拉選單
myMouse.position = (1108, 151)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

# 點選Import 出貨明細
myMouse.position = (1070, 189)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

# 點選瀏覽
myMouse.position = (597, 418)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

# 點選桌面
myMouse.position = (80, 153)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

# 輸入欲Import檔案名稱
myMouse.position = (267, 417)
myMouse.click(ms.Button.left, 1)
myKeyboard.tap(kb.Key.shift)
programToFind = '004_出貨明細.csv'
myKeyboard.type(programToFind)
myKeyboard.tap(kb.Key.enter)
time.sleep(4)

# 點選下一步
myMouse.position = (1021, 559)
myMouse.click(ms.Button.left, 1)
time.sleep(3)

# 點選下一步
myMouse.position = (178, 441)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

# 點選Apply auto mapping
myMouse.position = (248, 621)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

# 點選Apply
myMouse.position = (692, 231)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

# 點選下一步
myMouse.position = (1213, 623)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

# 點選繼續
myMouse.position = (725, 241)
myMouse.click(ms.Button.left, 1)
time.sleep(4)

myMouse.scroll(0, -100)
time.sleep(2)

# 點選Finish
myMouse.position = (291, 559)
myMouse.click(ms.Button.left, 2)
time.sleep(10)

# 點選Home
myMouse.position = (260, 96)
myMouse.click(ms.Button.left, 2)
time.sleep(4)
myKeyboard.tap(kb.Key.f5)

# %%
myMouse = ms.Controller()
myMouse.position 
# myMouse.click(ms.Button.left, 1)
# time.sleep(1.5)
# Out:
# (260, 96)
